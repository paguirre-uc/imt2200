# %% [markdown]
# # <img style="float: left; padding-right: 0.7cm; width: 3.0cm" src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/84/Escudo_de_la_Pontificia_Universidad_Cat%C3%B3lica_de_Chile.svg/179px-Escudo_de_la_Pontificia_Universidad_Cat%C3%B3lica_de_Chile.svg.png"> IMT 2200 - Introducción a Ciencia de Datos
# **Pontificia Universidad Católica de Chile**<br>
# **Semestre 2022-2**<br>
# **Profesora:** Paula Aguirre <br>
#
# ----

# %% [markdown]
# <h1 align="center">Interrogación 1</h1>
#
#
# ## Instrucciones Generales:
# * Esta Interrogación debe ser desarrollada completamente en lenguaje de programación Python.
#
# * Esta Interrogación cuenta de dos partes: una sección de preguntas breves de desarrollo (Parte 1), y una sección de trabajo práctico con datos (Parte 2). Responda ambas secciones en este mismo Notebook.
#
# * En la Parte 1, sólo se piden respuestas de texto. En la Parte 2, cada pregunta requiere un pequeño código, y una respuesta de texto corta si aplica.
#
# * El desarrollo del Notebook debe ser claro y ordenado, incluyendo anotaciones (markdown) y comentarios que permitan seguir fácilmente el código y los pasos implementados, y siguiendo buenas prácticas de programación. <br>
#
#
# * La entrega de la interrogación se realizará a través de Github.
# * Esta Interrogación debe desarrollarse de manera totalmente *individual*, de acuerdo a lo establecido en la sección de Integridad Académica en el programa del curso.
# * Está **estrictamente prohibido comunicarse con sus compañeros de curso o terceras personas** durante el desarrollo de esta interrogación.
# * Puede consultar documentación online y apuntes de todo tipo.
# * Se permiten preguntas de enunciado, **en español (no en Python)**.<br>
#
#
# * Ud. dispone de 1h 30m para desarrollar esta interrogación.
# * Recuerde **guardar frecuentemente sus avances en su repositorio personal de Github (commit/push)** para evitar pérdidas de trabajo o problemas de envío.<br>

# %% [markdown]
# # Parte 1: Preguntas de desarrollo (20 min).
#
# Responda brevemente las siguientes preguntas (sólo respuestas de texto). Escriba cada respuesta en una celda de markdown bajo la respectiva pregunta.

# %% [markdown]
# ### 1.1 ¿Qué ventajas pueden presentar los datos en formato JSON vs. formatos de datos estructurados como .csv?
# * Mayor flexibilidad para almacenar datos, dado que hay una estructura jerárquica adaptable, y no es necesario tener los mismos campos para todos los registros.
# * Ahorro de espacio de memoria al evitar grandes cantidades de datos nulo.
# * Facilidad para transmisión ia Web.

# %% [markdown]
# ### 1.2 Explique al menos una diferencia entre los formatos de datos HTML y XML.

# %% [markdown]
# * En HTML existe una estructura preestablecida de tags, mientras que en XML los tags son definidos por el usuario.

# %% [markdown]
# ### 1.3 Suponga que una cierta consultora política realiza un modelo predictivo para un próximo plebiscito, a partir del análisis de contenido de cerca de un millón de comentarios y mensajes publicados por los usuarios nacionales en la red social Twitter. ¿Qué tipo de sesgo(s) debería tenerse en consideración al utilizar este conjunto de datos? Mencione y explique al menos uno.

# %% [markdown]
# Principalmente sesgos de representación, ya que los usuarios de Twitter representan una muestra poco representativa del electorado, por ejemplo debido a : menor participación en la red de adultos mayores vs. jóvenes, cuentas falsas (bots), predominancia de usuarios altamente digitalizados, etc.

# %% [markdown]
# ### 1.4 Explique y explique al menos dos ventajas de utilizar códigos de Python para descargar un archivo de datos desde su URL, en lugar de simplemente hacer click y descargar los datos manualmente.

# %% [markdown]
# * Facilidad para reproducir y escalar códigos
# * Reproducibilidad científica
# * Trazabilidad de los conjuntos de datos usados en el análisis
# * Facilita compartir análisis y proyectos

# %% [markdown]
# ***
# ## Parte 2: Trabajo práctico con datos (60 min).
#
# En esta parte, cada pregunta debe ser respondida en base a un pequeño código. **No se evaluarán respuestas sin código**.

# %% [markdown]
# ### Análisis de datos IMDb.
#
# IMDb (Internet Movie Database) es una base de datos online con información relativa a películas, series de televisión, video juegos y streaming, incluyendo: datos generales, elencos, equipo de producción y dirección, resúmenes de la trama, trivia, ratings, y comentarios del público.
#
# Las bases de datos actualizadas de IMDb están disponibles en el siguiente link: https://datasets.imdbws.com/
#
# En este ejercicio, ud. trabajará con un subconjunto de estos datos, que ya está disponible en su repositorio personal en el siguiente archivo: `IMDB_data.csv`.

# %% [markdown]
# ### 2.1 Lea e inspeccione los datos.  Determine si hay columnas que deberían ser eliminadas. Si es el caso, justifique la razón para eliminar las columnas señaladas, e implemente su decisión.

# %%
import pandas as pd
import numpy as np

dat=pd.read_csv('IMDB_data.csv')
dat.head()
# Out:
#    Unnamed: 0      tconst  titleType                 primaryTitle  \
# 0           0  tt12891306      short                      Bounded
# 1           1  tt13613360      short                        Sarah
# 2           2  tt18548236  tvEpisode     6-Time Chernobyl on Fire
# 3           3   tt7608250      short                        Dirge
# 4           4   tt3531518  tvEpisode  Beacon Hill Preview, Part 2
#
#                  originalTitle  isAdult startYear endYear runtimeMinutes  \
# 0                      Bounded        0      2021      \N             \N
# 1                        Sarah        0      2016      \N             14
# 2     6-Time Chernobyl on Fire        0      2022      \N             \N
# 3                        Dirge        0      2017      \N              6
# 4  Beacon Hill Preview, Part 2        0      2014      \N             \N
#
#                    genres  averageRating  numVotes
# 0                   Short            NaN       NaN
# ...

# %%
dat.columns
# Out:
# Index(['Unnamed: 0', 'tconst', 'titleType', 'primaryTitle', 'originalTitle',
#        'isAdult', 'startYear', 'endYear', 'runtimeMinutes', 'genres',
#        'averageRating', 'numVotes'],
#       dtype='object')

# %%
dat=dat.drop(columns=['Unnamed: 0'])

# %% [markdown]
# ### 2.2 Determine el tipo de datos que debería asignarse a cada columna restante. Justifique brevemente para cada columna, y haga los cambios necesarios.

# %%
dat=dat.replace('\\N',np.nan)
dat.head()
# Out:
#        tconst  titleType                 primaryTitle  \
# 0  tt12891306      short                      Bounded
# 1  tt13613360      short                        Sarah
# 2  tt18548236  tvEpisode     6-Time Chernobyl on Fire
# 3   tt7608250      short                        Dirge
# 4   tt3531518  tvEpisode  Beacon Hill Preview, Part 2
#
#                  originalTitle  isAdult startYear endYear runtimeMinutes  \
# 0                      Bounded        0      2021     NaN            NaN
# 1                        Sarah        0      2016     NaN             14
# 2     6-Time Chernobyl on Fire        0      2022     NaN            NaN
# 3                        Dirge        0      2017     NaN              6
# 4  Beacon Hill Preview, Part 2        0      2014     NaN            NaN
#
#                    genres  averageRating  numVotes
# 0                   Short            NaN       NaN
# 1       Crime,Drama,Short            NaN       NaN
# ...

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174629 entries, 0 to 174628
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          174629 non-null  object
#  1   titleType       174629 non-null  object
#  2   primaryTitle    174628 non-null  object
#  3   originalTitle   174628 non-null  object
#  4   isAdult         174629 non-null  int64
#  5   startYear       151478 non-null  object
#  6   endYear         1798 non-null    object
#  7   runtimeMinutes  47016 non-null   object
#  8   genres          166560 non-null  object
#  9   averageRating   24004 non-null   float64
#  10  numVotes        24004 non-null   float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 14.7+ MB

# %%
dat['isAdult']=dat['isAdult'].astype('bool')
dat['genres']=dat['genres'].astype('category')
dat['startYear']=dat['startYear'].astype('float')
dat['endYear']=dat['endYear'].astype('float')
dat['runtimeMinutes']=dat['runtimeMinutes'].astype('float')

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174629 entries, 0 to 174628
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          174629 non-null  object
#  1   titleType       174629 non-null  object
#  2   primaryTitle    174628 non-null  object
#  3   originalTitle   174628 non-null  object
#  4   isAdult         174629 non-null  bool
#  5   startYear       151478 non-null  float64
#  6   endYear         1798 non-null    float64
#  7   runtimeMinutes  47016 non-null   float64
#  8   genres          166560 non-null  category
#  9   averageRating   24004 non-null   float64
#  10  numVotes        24004 non-null   float64
# dtypes: bool(1), category(1), float64(5), object(4)
# memory usage: 12.5+ MB

# %% [markdown]
# ### 2.3 Genere un nuevo dataframe que contenga sólo datos relativos a películas (movies). ¿Cuántas películas hay en la base de datos?

# %%
movies=dat[dat['titleType']=='movie'].reset_index(drop=True)
movies
# Out:
#            tconst titleType                  primaryTitle  \
# 0       tt0807037     movie   Ricardo Montalbán en España
# 1       tt7049272     movie              Above the Clouds
# 2       tt0091935     movie  100 Ways to Murder Your Wife
# 3       tt3690152     movie                     Potroseni
# 4       tt1452874     movie           I figli della morte
# ...           ...       ...                           ...
# 11690  tt12899360     movie              Bears of Durango
# 11691   tt2638480     movie                    Yvy Maraey
# 11692   tt0247208     movie                Bhakta Shabari
# 11693   tt0040387     movie        The Honor of the House
# 11694   tt0774030     movie                     48 Angels
#
#                      originalTitle  isAdult  startYear  endYear  \
# 0      Ricardo Montalbán en España    False     1985.0      NaN
# 1                 Above the Clouds    False     2018.0      NaN
# 2                 Sha qi er ren zu    False     1986.0      NaN
# ...

# %% [markdown]
# ### 2.4 ¿Cuál es el género de películas más numeroso en el dataset?

# %%
movies['genres']=movies['genres'].str.split(',',expand=True)[0] 
#opcional, no cambia la respuesta

# %%
movies['genres'].value_counts()
#Drama es la más numerosa
# Out:
# Drama          2863
# Documentary    1959
# Comedy         1809
# Action          951
# Horror          440
# Crime           394
# Adventure       371
# Biography       253
# Thriller        223
# Romance         149
# Adult           136
# Animation       103
# Western          99
# Fantasy          91
# Sci-Fi           86
# Family           78
# Mystery          64
# Musical          52
# Music            50
# History          34
# Sport            30
# War              25
# Reality-TV        3
# Game-Show         1
# Name: genres, dtype: int64

# %% [markdown]
# ### 2.5 ¿Cuál es su género de película favorito? Elija un género de películas (indique claramente cúal), y seleccione todas las películas de dicho género, con rating mayor a 8.0, y publicadas entre 2015 y hoy. Luego, ordene por rating de mayor a menor.

# %%
#puede ser cualquier género favorito. No importa si hay cero resultados si la selección está bien hecha.
fav_genre='Drama'
fav=movies[(movies['genres']==fav_genre) &(movies['startYear']>=2005) & (movies['startYear']<=2022)]
fav.sort_values(by='averageRating',ascending=False)
# Out:
#            tconst titleType            primaryTitle           originalTitle  \
# 1707   tt21194300     movie                Ghunghat                Ghunghat
# 5187   tt13222524     movie  Finding Your True Self  Finding Your True Self
# 10370   tt7929604     movie                 Ariadne                 Ariadne
# 9906   tt14282256     movie  Where the Merrows Roam  Where the Merrows Roam
# 10524   tt2169050     movie     Howling at the Moon     Howling at the Moon
# ...           ...       ...                     ...                     ...
# 11546   tt7430992     movie                    Raju                    Raju
# 11560   tt0891464     movie               Daijishin               Daijishin
# 11590  tt13782006     movie           Ulla Kadathal           Ulla Kadathal
# 11670  tt18312496     movie      Innanu Aa Kalyanam      Innanu Aa Kalyanam
# 11680  tt13057476     movie            Thiruttu VCD            Thiruttu VCD
#
# ...

# %% [markdown]
# ### 2.6 Para los datos relativos a películas se considerará que dos o más registros son duplicados, si se repite el título primario, y el año (de lo contrario, podría ser un remake). Determine la cantidad de duplicados existentes en el conjunto de datos relativo a películas, y elimine todos o algunos de ellos según le parezca apropiado. Justifique brevemente su decisión.

# %%
movies[movies.duplicated(subset=['primaryTitle','startYear'],keep=False)].sort_values(by='primaryTitle')
# Out:
#            tconst titleType   primaryTitle  originalTitle  isAdult  startYear  \
# 1392    tt6083154     movie              A              A    False        NaN
# 6707   tt12573312     movie              A              A    False        NaN
# 7578   tt15531596     movie        Abigail        Abigail    False        NaN
# 10105  tt10055510     movie        Abigail        Abigail    False        NaN
# 9956    tt7157442     movie      Final Cut      Final Cut    False        NaN
# 9958    tt8936860     movie      Final Cut      Final Cut    False        NaN
# 417    tt13836434     movie        Matched        Matched    False        NaN
# 5257    tt2382326     movie        Matched        Matched    False        NaN
# 1937    tt5037382     movie        Odyssey        Odyssey    False        NaN
# 5430    tt9788564     movie        Odyssey        Odyssey    False        NaN
# 4456    tt8311492     movie  State of Mind  State of Mind    False        NaN
# ...

# %% [markdown]
# ### 2.7 ¿Cuál es la duración promedio, máxima y mínima de las películas en su base de datos?

# %%
movies.describe()
# Out:
#           startYear  endYear  runtimeMinutes  averageRating       numVotes
# count  10127.000000      0.0     7377.000000    5252.000000    5252.000000
# mean    1990.130246      NaN       89.461299       6.147030    3139.910129
# std       30.307847      NaN       26.960849       1.355591   25057.945952
# min     1908.000000      NaN        5.000000       1.000000       5.000000
# 25%     1971.000000      NaN       74.000000       5.300000      18.000000
# 50%     2002.000000      NaN       89.000000       6.300000      59.000000
# 75%     2015.000000      NaN      100.000000       7.100000     309.250000
# max     2025.000000      NaN      600.000000      10.000000  686955.000000

# %% [markdown]
# ### 2.8 Elimine del dataset las películas para las cuales el año o la duración son faltantes o nulos.

# %%
movies.dropna(subset=['startYear','averageRating'],inplace=True)

# %% [markdown]
# ### 2.9 ¿Cuál es su género de película favorito? Elija un género de películas (indique claramente cúal), y seleccione todas las películas de dicho género, con rating mayor a 8.0, y publicadas entre 2015 y hoy. Luego, ordene por rating de mayor a menor.
#
# De esta forma, habrá generado una lista ordenada de películas de su gusto para ver durante el fin de semana.

# %%
movies[(movies['genres']=='Drama') & (movies['averageRating']>8) & (movies['startYear']>2015) & (movies['startYear']<2020)].sort_values(by='averageRating')
# Out:
#            tconst titleType  \
# 3021    tt3554336     movie
# 6892    tt9182478     movie
# 5243    tt5458618     movie
# 6243    tt9130246     movie
# 7303    tt3828218     movie
# 8288    tt4102800     movie
# 131     tt2275702     movie
# 5440    tt8690886     movie
# 6401    tt6932748     movie
# 4401    tt5684312     movie
# 9546    tt5492684     movie
# 9062   tt10644910     movie
# 6250    tt7655282     movie
# 10456  tt10440846     movie
# 10370   tt7929604     movie
#
#                                             primaryTitle  \
# 3021                                           Loslassen
# 6892                                             Kolambi
# 5243                                     HeartLand Blues
# 6243                                                Naal
# 7303                                     The Dry Cleaner
# 8288                                   Coração Atlântico
# 131                                    Alone in a Valley
# ...

# %% [markdown]
# ### 2.10 ¿Ha aumentado la duración de las películas en el tiempo? Para responder esta pregunta, realice un gráfico de año vs. duración de la película (gráfico de dispersión), y comente. Incluya en su gráfico: título y etiquetas de ejes.

# %%
fig=plt.figure(figsize=(8,8))
ax=fig.add_subplot(111)

ax.plot(movies['startYear'],movies['runtimeMinutes'],'.',alpha=0.4)
ax.set_xlabel('Año')
ax.set_ylabel('Duración en minutos')

ax.set_title('Duración de películas a lo largo del tiempo')
# Out:
# Text(0.5, 1.0, 'Duración de películas a lo largo del tiempo')
