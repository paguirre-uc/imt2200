# %%
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd
import requests
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # <img style="float: left; padding: 0px 10px 0px 0px;" src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/84/Escudo_de_la_Pontificia_Universidad_Cat%C3%B3lica_de_Chile.svg/1920px-Escudo_de_la_Pontificia_Universidad_Cat%C3%B3lica_de_Chile.svg.png"  width="80" /> IMT2200 - Introducción a Ciencia de Datos
#
# ## Clase 15: Análisis Exploratorio de Datos Univariado
# ---

# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
font = {'family' : 'normal','size'   : 14}
import matplotlib
matplotlib.rc('font', **font)
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Datos de ejemplo.

# %%
dfe=pd.read_csv('datos_clase15.csv')
dfe
# Out:
#          Valores  Category1 Category2
# 0            6.4         15         P
# 1            5.1         15         P
# 2            4.8         15         P
# 3            5.2         15         P
# 4            5.3         15         P
# ...          ...        ...       ...
# 2959235      7.0          8         P
# 2959236      6.5          8         P
# 2959237      5.0          8         P
# 2959238      6.6          8         P
# 2959239      6.6          8         P
#
# [2959240 rows x 3 columns]

# %%
import seaborn as sns
sns.set_style("ticks")
sns.set_context("talk")

fig=plt.figure(figsize=(8,8))
ax=fig.add_subplot(111)

sns.histplot(data=dfe,x='Valores',kde=True);
ax.set_ylabel('Cuentas')
fig.savefig('histogram_kde.jpg',dpi=300)

# %%
import seaborn as sns
sns.set_style("ticks")
sns.set_context("talk")

fig=plt.figure(figsize=(8,8))
ax=fig.add_subplot(111)

sns.kdeplot(data=dfe,x='Valores',ax=ax,gridsize=20);
ax.set_ylabel('KDE')
# Out:
# Text(0, 0.5, 'KDE')

# %% [markdown]
# **Notas:** Revise la documentación de `seaborn.histplot`y verifique cómo cambian sus gráficos al cmabiar los argumentos:`bins`,`stat`,`kde`y otros que llamen su atención.

# %%
import numpy
mu=dfe['Valores'].mean()
sigma = dfe['Valores'].std()
samples = numpy.random.normal(mu, sigma, len(dfe))
dfe['Valores2']=samples
dfe
# Out:
#          Valores  Category1 Category2  Valores2
# 0            6.4         15         P  7.128040
# 1            5.1         15         P  6.274148
# 2            4.8         15         P  5.449280
# 3            5.2         15         P  6.545120
# 4            5.3         15         P  6.098360
# ...          ...        ...       ...       ...
# 2959235      7.0          8         P  6.006033
# 2959236      6.5          8         P  5.661174
# 2959237      5.0          8         P  4.301293
# 2959238      6.6          8         P  6.524739
# 2959239      6.6          8         P  5.025980
#
# [2959240 rows x 4 columns]

# %%
import seaborn as sns
sns.set_style("ticks")
sns.set_context("talk")

fig=plt.figure(figsize=(16,8))
ax1=fig.add_subplot(121)
ax2=fig.add_subplot(122)

mu=dfe.Valores.mean()
sigma=dfe.Valores.std()

print(sigma,mu)
sns.histplot(data=dfe,x='Valores',ax=ax1,stat='density',bins=20,);
sns.histplot(data=dfe,x='Valores2',ax=ax2,stat='density',bins=20,color='g',alpha=0.5);
ax2.set_xlabel('Valores')

ax1.set_ylabel('Cuentas')
ax2.set_ylabel('Cuentas')

ax1.text(1.5,0.6,r'$\mu$ = 6.02',color='tab:blue')
ax1.text(1.5,0.55,r'$\sigma$ = 0.76',color='tab:blue')

ax2.text(1.5,0.6,r'$\mu$ = 6.02',color='tab:green')
ax2.text(1.5,0.55,r'$\sigma$ = 0.76',color='tab:green')

for ax in [ax1,ax2]:
    ax.set_xlim(1,9)
    ax.set_ylim(0,0.7)


fig.savefig('histogram2.jpg',dpi=300)
# Out:
# 0.7594427170118232 6.0171651505202

# %% [markdown]
# ### Gráficos de caja

# %%
import seaborn as sns

fig=plt.figure(figsize=(8,8))
ax=fig.add_subplot(111)

sns.boxplot(data=dfe,y='Valores',ax=ax)
fig.savefig('boxplot.jpg',dpi=300)

# %%
import seaborn as sns

fig=plt.figure(figsize=(8,8))
ax=fig.add_subplot(111)

sns.violinplot(data=dfe,y='Valores',ax=ax, gridsize=20)
fig.savefig('boxplot.jpg',dpi=300)

# %%
dfe['Valores'].describe()
# Out:
# count    2.959240e+06
# mean     6.017165e+00
# std      7.594427e-01
# min      1.100000e+00
# 25%      5.600000e+00
# 50%      6.200000e+00
# 75%      6.600000e+00
# max      7.000000e+00
# Name: Valores, dtype: float64
